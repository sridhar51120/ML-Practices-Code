# %% [markdown]
# <a href="https://colab.research.google.com/github/sridhar51120/BIT_workshop/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file = open('/content/test.txt','r')
# print(type(file.read()))
# print(file.readlines())
text  = []
for i in file.readlines():
  text.append(i)
  print(i[:],end=' ')
# print(text)
# file.close()
# print(text)
# Out:
# s.kdfmskdjfnsdf
#  asdk sdkjsdf
#  sadkjsndk.jsd
#  asdjksd sad

# %%
for i in text:
  print(i[:])
# Out:
# s.kdfmskdjfnsdf
#
# asdk sdkjsdf
#
# sadkjsndk.jsd
#
# asdjksd sad

# %%
value = input()
print(type(value))

for i in text:
  if(str(i) == value):
    print(i)
  else:
    print("Nothing")
# Out:
# asdk sdkjsdf
# <class 'str'>
# Nothing
# Nothing
# Nothing
# Nothing
