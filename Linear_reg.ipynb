# %% [markdown]
# <a href="https://colab.research.google.com/github/sridhar51120/BIT_workshop/blob/main/Linear_reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("Done")
# Out:
# Done

# %%
data = pd.read_csv('weight-height.csv')
# data.head()

# %%
print(data)
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
data = data[0:10]
data.plot(x='Height',y='Weight',style='o')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
x = pd.DataFrame(data['Height'])
print(x)

y = pd.DataFrame(data['Weight'])
print(y)
# Out:
#       Height
# 0  73.847017
# 1  68.781904
# 2  74.110105
# 3  71.730978
# 4  69.881796
# 5  67.253016
# 6  68.785081
# 7  68.348516
# 8  67.018950
# 9  63.456494
#        Weight
# 0  241.893563
# 1  162.310473
# 2  212.740856
# 3  220.042470
# 4  206.349801
# 5  152.212156
# 6  183.927889
# 7  167.971110
# 8  175.929440
# 9  156.399676

# %%
print(x)
# from sklearn.model_selection import train_test_split

# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)
# Out:
# [1 1 2 3 4 4 5 6 7 7 8 9]

# %%
print(x_train.shape)
print("\n")
print(x_test.shape)
print("\n")
print(y_train.shape)
print('\n')
print(y_test.shape)
# Out:
# (8, 1)
#
#
# (2, 1)
#
#
# (8, 1)
#
#
# (2, 1)

# %%
from sklearn.linear_model import LinearRegression

regression = LinearRegression()
regression.fit(x_train,y_train)

print(f"Intercept {regression.intercept_}")
# Out:
# Intercept [-676.2793676]

# %%
print(f"Slope :: {regression.coef_}")
# Out:
# Slope :: [[12.45551337]]

# %%
print(y_test)
# Out:
#        Weight
# 2  212.740856
# 9  156.399676

# %%
y_pred = regression.predict(x_test)
y_pred = pd.DataFrame(y_pred,columns=['Height'])
y_pred
# Out:
#        Height
# 0  246.800041
# 1  114.103841

# %%
from sklearn import metrics

print(f"Mean Absolute Error: {metrics.mean_absolute_error(y_test,y_pred)}")
print(f"Mean Squared Error: {metrics.mean_squared_error(y_test,y_pred)}")
print(f"Root Mean Squared Error :: {np.sqrt(metrics.mean_squared_error(y_test,y_pred))}")
# Out:
# Mean Absolute Error: 38.177510101296235
# Mean Squared Error: 1474.4828773875327
# Root Mean Squared Error :: 38.398995786186035

# %% [markdown]
# ## ***Regression Line***

# %%
x = np.array([1, 1, 2, 3, 4, 4, 5, 6, 7, 7, 8, 9])
y = np.array([13, 14, 17, 12, 23, 24, 25, 25, 24, 28, 32, 33])

plt.plot(x, y, 'o', color='green')

m, b = np.polyfit(x, y, 1)

plt.plot(x, m*x+b, color='red')

# %% [markdown]
# # **Predict Values**
