# %% [markdown]
# <a href="https://colab.research.google.com/github/sridhar51120/BIT_workshop/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import pandas as pd

data = pd.read_csv("/content/iemocap_full_dataset.csv")

# print(data)
# Out:
#        session  method gender emotion  n_annotators  agreement  \
# 0            1  script      F     neu             3          3
# 1            1  script      F     fru             3          2
# 2            1  script      F     xxx             0          0
# 3            1  script      F     sur             3          2
# 4            1  script      F     neu             3          2
# ...        ...     ...    ...     ...           ...        ...
# 10034        5   impro      F     neu             3          2
# 10035        5   impro      F     neu             3          2
# 10036        5   impro      F     neu             3          2
# 10037        5   impro      F     neu             3          2
# 10038        5   impro      F     neu             3          3
#
#                                                     path
# 0      Session1/sentences/wav/Ses01F_script02_1/Ses01...
# 1      Session1/sentences/wav/Ses01F_script02_1/Ses01...
# ...

# %%
data.columns
# Out:
# Index(['session', 'method', 'gender', 'emotion', 'n_annotators', 'agreement',
#        'path'],
#       dtype='object')

# %%
from os import path
print(type(data['path']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
for i in data['path']:
  print(i,"\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M000.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M001.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M002.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M003.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M004.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M005.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M006.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M007.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M008.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M009.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M010.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M011.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M012.wav
#
# Session4/sentences/wav/Ses04F_impro04/Ses04F_impro04_M013.wav
#
# ...

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame(data)
# print(type(data))
for i in data['path']:
  print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_F033.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_F034.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_F035.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_F036.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_F037.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_F038.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_F039.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_F040.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_F041.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_F042.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_M000.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_M001.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_M002.wav
# Session3/sentences/wav/Ses03M_impro03/Ses03M_impro03_M003.wav
# ...

# %%
import pandas as pd
import numpy as np

for i in data['path'][1]:
  print(i,end='')
# Out:
# Session1/sentences/wav/Ses01F_script02_1/Ses01F_script02_1_F001.wav
